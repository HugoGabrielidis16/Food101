# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuuuugo/Food101/blob/main/Food101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi -L #Factory reset the runtime until it is set to a Tesla T4
# Out:
# zsh:1: command not found: nvidia-smi

# %%
# !brew install wget
# Out:
# Running `brew update --preinstall`...
# ==> Auto-updated Homebrew!
# Updated 3 taps (hashicorp/tap, homebrew/core and homebrew/cask).
# ==> New Formulae
# micro_inetd                spirv-headers              wb32-dfu-updater_cli
# ==> Updated Formulae
# Updated 236 formulae.
# ==> New Casks
# osu
# ==> Updated Casks
# Updated 120 casks.
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:50c30
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2022-
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:c0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/manifests/1.1.1n
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/blobs/sha256:a7fd5c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/manifests/1.21.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/blobs/sha256:b90e0d7a4319c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Installing dependencies for wget: libunistring, ca-certificates and openssl@1.1
# ==> Installing wget dependency: libunistring
# ==> Pouring libunistring--1.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libunistring/1.0: 56 files, 4.8MB
# ==> Installing wget dependency: ca-certificates
# ==> Pouring ca-certificates--2022-04-26.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /usr/local/Cellar/ca-certificates/2022-04-26: 3 files, 215.6KB
# ==> Installing wget dependency: openssl@1.1
# ==> Pouring openssl@1.1--1.1.1n.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/openssl@1.1/1.1.1n: 8,089 files, 18.5MB
# ==> Installing wget
# ==> Pouring wget--1.21.3.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/wget/1.21.3: 89 files, 4.2MB
# ==> Running `brew cleanup wget`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Warning: The following dependents of upgraded formulae are outdated but will not
# be upgraded because they are not bottled:
#   swi-prolog
# ==> Upgrading 11 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# cryptominisat 5.8.0_1 -> 5.8.0_2, glib 2.70.1 -> 2.72.1, gnutls 3.6.16_1 -> 3.7.4, gobject-introspection 1.70.0_1 -> 1.72.0, guile 3.0.7_2 -> 3.0.8, harfbuzz 3.1.1 -> 4.2.1, ffmpeg 4.4.1_3 -> 5.0.1, mysql 8.0.27 -> 8.0.28_1, nghttp2 1.46.0 -> 1.47.0, python@3.9 3.9.8 -> 3.9.12, unbound 1.13.2_1 -> 1.15.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.47.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:bfffdfc
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.15.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:b00a31b7ef
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/manifests/1.23
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdbm/blobs/sha256:d52ed8dbb258f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.1.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/blobs/sha256:1eaadc077
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.38.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:ef58d1c3319
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/manifests/3.9.12
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python/3.9/blobs/sha256:a31f2a2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.72.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:92937c6c142a2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.4.7
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:bae30841fa
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/guile/manifests/3.0.8
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/guile/blobs/sha256:e95549a938b1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.18.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/blobs/sha256:dc2e93619
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.24.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:6db6726e6b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.7.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:3ec77636e41
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.12.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:e43fe6566
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.14.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:b2d6381
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2022.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:59bc0ef6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.14_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:c499695d445
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.7.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:9c6cae85331
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/manifests
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gobject-introspection/blobs/sha
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/70.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:f124a30b9ecb
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/4.2.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:d6a5c5591
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:5acea94faccf
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg/manifests/9e
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg/blobs/sha256:085e31212006e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.1.5
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:db79b777e1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.2.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:3f1bdbf8361bd
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/2.3.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:60fb7784b3
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.3.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:e5f4fba0b45d08
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/1.8.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/blobs/sha256:e97f700c8a5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.12
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:4a9e4b177e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/blobs/sha256:263d4181
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:5f1bac9175
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.7
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:611f5337f0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.13.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:7fbbf5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.5.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/blobs/sha256:4464e4eec498
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/manifests/1.3.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/blobs/sha256:2edc8dddafb07
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/manifests/1.1.0-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/blobs/sha256:0878aea
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/2.0.2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/blobs/sha256:ed69e5f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.0.22
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/blobs/sha256:cb7bd018480f1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.2-2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:c79db7b0ca3d6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.6.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/blobs/sha256:a241d5e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/blobs/sha256:68816323
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/manifests/3.0.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/blobs/sha256:9c106b35b00ef
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/5.0.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/blobs/sha256:ab8be194324
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libcbor/manifests/0.9.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libcbor/blobs/sha256:445ccae0ed
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libfido2/manifests/1.10.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libfido2/blobs/sha256:be93faeb2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/protobuf/manifests/3.19.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/protobuf/blobs/sha256:a6e39ca1c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mysql/manifests/8.0.28_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mysql/blobs/sha256:ce886ee6265b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/manifests/1.18.1_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/blobs/sha256:e276dddce0e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nghttp2/manifests/1.47.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nghttp2/blobs/sha256:4a5aa98db8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/boost/manifests/1.78.0_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/boost/blobs/sha256:16e54dc0a542
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cryptominisat/manifests/5.8.0_2
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cryptominisat/blobs/sha256:291f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Upgrading unbound
#   1.13.2_1 -> 1.15.0
#
# ==> Installing dependencies for unbound: libnghttp2
# ==> Installing unbound dependency: libnghttp2
# ==> Pouring libnghttp2--1.47.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libnghttp2/1.47.0: 13 files, 678.6KB
# ==> Installing unbound
# ==> Pouring unbound--1.15.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/unbound/1.15.0: 58 files, 5.8MB
# ==> Running `brew cleanup unbound`...
# Removing: /usr/local/Cellar/unbound/1.13.2_1... (57 files, 5.7MB)
# ==> Upgrading python@3.9
#   3.9.8 -> 3.9.12
#
# ==> Installing dependencies for python@3.9: gdbm, readline and sqlite
# ==> Installing python@3.9 dependency: gdbm
# ==> Pouring gdbm--1.23.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/gdbm/1.23: 24 files, 972.9KB
# ==> Installing python@3.9 dependency: readline
# ==> Pouring readline--8.1.2.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/readline/8.1.2: 48 files, 1.6MB
# ==> Installing python@3.9 dependency: sqlite
# ==> Pouring sqlite--3.38.3.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/sqlite/3.38.3: 11 files, 4.4MB
# ==> Installing python@3.9
# ==> Pouring python@3.9--3.9.12.big_sur.bottle.tar.gz
# ==> /usr/local/Cellar/python@3.9/3.9.12/bin/python3 -m ensurepip
# ==> /usr/local/Cellar/python@3.9/3.9.12/bin/python3 -m pip install -v --no-deps
# 🍺  /usr/local/Cellar/python@3.9/3.9.12: 3,088 files, 55.6MB
# ==> Running `brew cleanup python@3.9`...
# Removing: /usr/local/Cellar/python@3.9/3.9.7_1... (3,188 files, 56.5MB)
# Removing: /usr/local/Cellar/python@3.9/3.9.8... (3,215 files, 57.3MB)
# ==> Upgrading glib
#   2.70.1 -> 2.72.1
#
# ==> Pouring glib--2.72.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/glib/2.72.1: 449 files, 20.5MB
# ==> Running `brew cleanup glib`...
# Removing: /usr/local/Cellar/glib/2.70.1... (444 files, 21MB)
# ==> Upgrading guile
#   3.0.7_2 -> 3.0.8
#
# ==> Installing dependencies for guile: libtool
# ==> Installing guile dependency: libtool
# ==> Pouring libtool--2.4.7.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtool/2.4.7: 75 files, 3.8MB
# ==> Installing guile
# ==> Pouring guile--3.0.8.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/guile/3.0.8: 846 files, 62.8MB
# ==> Running `brew cleanup guile`...
# Removing: /usr/local/Cellar/guile/3.0.7... (838 files, 56.8MB)
# Removing: /usr/local/Cellar/guile/3.0.7_2... (838 files, 56.8MB)
# ==> Upgrading gnutls
#   3.6.16_1 -> 3.7.4
#
# ==> Installing dependencies for gnutls: libtasn1 and p11-kit
# ==> Installing gnutls dependency: libtasn1
# ==> Pouring libtasn1--4.18.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libtasn1/4.18.0: 61 files, 650.5KB
# ==> Installing gnutls dependency: p11-kit
# ==> Pouring p11-kit--0.24.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/p11-kit/0.24.1: 67 files, 3.6MB
# ==> Installing gnutls
# ==> Pouring gnutls--3.7.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/gnutls/3.7.4: 1,284 files, 11MB
# ==> Running `brew cleanup gnutls`...
# Removing: /usr/local/Cellar/gnutls/3.6.16_1... (1,250 files, 11MB)
# ==> Upgrading gobject-introspection
#   1.70.0_1 -> 1.72.0
#
# ==> Installing dependencies for gobject-introspection: freetype, fontconfig, xorgproto, libxcb and libx11
# ==> Installing gobject-introspection dependency: freetype
# ==> Pouring freetype--2.12.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/freetype/2.12.0: 67 files, 2.4MB
# ==> Installing gobject-introspection dependency: fontconfig
# ==> Pouring fontconfig--2.14.0.big_sur.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /usr/local/Cellar/fontconfig/2.14.0/bin/fc-cache -frv
# 🍺  /usr/local/Cellar/fontconfig/2.14.0: 84 files, 2.3MB
# ==> Installing gobject-introspection dependency: xorgproto
# ==> Pouring xorgproto--2022.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/xorgproto/2022.1: 264 files, 3.9MB
# ==> Installing gobject-introspection dependency: libxcb
# ==> Pouring libxcb--1.14_2.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libxcb/1.14_2: 2,452 files, 6.9MB
# ==> Installing gobject-introspection dependency: libx11
# ==> Pouring libx11--1.7.5.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libx11/1.7.5: 1,062 files, 7MB
# ==> Installing gobject-introspection
# ==> Pouring gobject-introspection--1.72.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/gobject-introspection/1.72.0: 193 files, 13.0MB
# ==> Running `brew cleanup gobject-introspection`...
# Removing: /usr/local/Cellar/gobject-introspection/1.70.0_1... (191 files, 13.0MB)
# ==> Upgrading harfbuzz
#   3.1.1 -> 4.2.1
#
# ==> Installing dependencies for harfbuzz: icu4c
# ==> Installing harfbuzz dependency: icu4c
# ==> Pouring icu4c--70.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/icu4c/70.1: 261 files, 74.4MB
# ==> Installing harfbuzz
# ==> Pouring harfbuzz--4.2.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/harfbuzz/4.2.1: 68 files, 7.8MB
# ==> Running `brew cleanup harfbuzz`...
# Removing: /usr/local/Cellar/harfbuzz/3.1.1... (68 files, 7.5MB)
# ==> Upgrading ffmpeg
#   4.4.1_3 -> 5.0.1
#
# ==> Installing dependencies for ffmpeg: imath, jpeg, openexr, webp, libvmaf, aom, frei0r, fribidi, libbluray, mbedtls, librist, little-cms2, rav1e, flac, libsndfile, rubberband, sdl2, zstd, libarchive, tesseract and zimg
# ==> Installing ffmpeg dependency: imath
# ==> Pouring imath--3.1.5.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/imath/3.1.5: 49 files, 924.8KB
# ==> Installing ffmpeg dependency: jpeg
# ==> Pouring jpeg--9e.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/jpeg/9e: 21 files, 955.5KB
# ==> Installing ffmpeg dependency: openexr
# ==> Pouring openexr--3.1.5.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/openexr/3.1.5: 194 files, 6.0MB
# ==> Installing ffmpeg dependency: webp
# ==> Pouring webp--1.2.2.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/webp/1.2.2: 41 files, 2.5MB
# ==> Installing ffmpeg dependency: libvmaf
# ==> Pouring libvmaf--2.3.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libvmaf/2.3.1: 234 files, 7.2MB
# ==> Installing ffmpeg dependency: aom
# ==> Pouring aom--3.3.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/aom/3.3.0: 23 files, 13.4MB
# ==> Installing ffmpeg dependency: frei0r
# ==> Pouring frei0r--1.8.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/frei0r/1.8.0: 127 files, 6MB
# ==> Installing ffmpeg dependency: fribidi
# ==> Pouring fribidi--1.0.12.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/fribidi/1.0.12: 67 files, 625.9KB
# ==> Installing ffmpeg dependency: libbluray
# ==> Pouring libbluray--1.3.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libbluray/1.3.1: 21 files, 941.8KB
# ==> Installing ffmpeg dependency: mbedtls
# ==> Pouring mbedtls--3.1.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/mbedtls/3.1.0: 152 files, 10.5MB
# ==> Installing ffmpeg dependency: librist
# ==> Pouring librist--0.2.7.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/librist/0.2.7: 28 files, 703.4KB
# ==> Installing ffmpeg dependency: little-cms2
# ==> Pouring little-cms2--2.13.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/little-cms2/2.13.1: 21 files, 1.3MB
# ==> Installing ffmpeg dependency: rav1e
# ==> Pouring rav1e--0.5.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/rav1e/0.5.1: 13 files, 118.9MB
# ==> Installing ffmpeg dependency: flac
# ==> Pouring flac--1.3.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/flac/1.3.4: 57 files, 2.6MB
# ==> Installing ffmpeg dependency: libsndfile
# ==> Pouring libsndfile--1.1.0.big_sur.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/libsndfile/1.1.0: 48 files, 1.2MB
# ==> Installing ffmpeg dependency: rubberband
# ==> Pouring rubberband--2.0.2.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/rubberband/2.0.2: 12 files, 1.1MB
# ==> Installing ffmpeg dependency: sdl2
# ==> Pouring sdl2--2.0.22.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/sdl2/2.0.22: 92 files, 5.7MB
# ==> Installing ffmpeg dependency: zstd
# ==> Pouring zstd--1.5.2.big_sur.bottle.2.tar.gz
# 🍺  /usr/local/Cellar/zstd/1.5.2: 31 files, 2.4MB
# ==> Installing ffmpeg dependency: libarchive
# ==> Pouring libarchive--3.6.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libarchive/3.6.1: 62 files, 3.6MB
# ==> Installing ffmpeg dependency: tesseract
# ==> Pouring tesseract--5.1.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/tesseract/5.1.0: 58 files, 30MB
# ==> Installing ffmpeg dependency: zimg
# ==> Pouring zimg--3.0.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/zimg/3.0.4: 27 files, 2.2MB
# ==> Installing ffmpeg
# ==> Pouring ffmpeg--5.0.1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/ffmpeg/5.0.1: 272 files, 51.6MB
# ==> Running `brew cleanup ffmpeg`...
# Removing: /usr/local/Cellar/ffmpeg/4.4.1_3... (276 files, 51MB)
# ==> Upgrading mysql
#   8.0.27 -> 8.0.28_1
#
# ==> Installing dependencies for mysql: libcbor, libfido2 and protobuf
# ==> Installing mysql dependency: libcbor
# ==> Pouring libcbor--0.9.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libcbor/0.9.0: 31 files, 161.7KB
# ==> Installing mysql dependency: libfido2
# ==> Pouring libfido2--1.10.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/libfido2/1.10.0: 510 files, 1MB
# ==> Installing mysql dependency: protobuf
# ==> Pouring protobuf--3.19.4.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/protobuf/3.19.4: 270 files, 19.6MB
# ==> Installing mysql
# ==> Pouring mysql--8.0.28_1.big_sur.bottle.tar.gz
# ==> Caveats
# We've installed your MySQL database without a root password. To secure it run:
#     mysql_secure_installation
#
# MySQL is configured to only allow connections from localhost by default
#
# To connect run:
#     mysql -uroot
#
# To restart mysql after an upgrade:
#   brew services restart mysql
# Or, if you don't want/need a background service you can just run:
#   /usr/local/opt/mysql/bin/mysqld_safe --datadir=/usr/local/var/mysql
# ==> Summary
# 🍺  /usr/local/Cellar/mysql/8.0.28_1: 304 files, 294.3MB
# ==> Running `brew cleanup mysql`...
# Removing: /usr/local/Cellar/mysql/8.0.27... (304 files, 294MB)
# ==> Upgrading nghttp2
#   1.46.0 -> 1.47.0
#
# ==> Installing dependencies for nghttp2: c-ares
# ==> Installing nghttp2 dependency: c-ares
# ==> Pouring c-ares--1.18.1_1.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/c-ares/1.18.1_1: 87 files, 645.5KB
# ==> Installing nghttp2
# ==> Pouring nghttp2--1.47.0.big_sur.bottle.tar.gz
# 🍺  /usr/local/Cellar/nghttp2/1.47.0: 17 files, 2.2MB
# ==> Running `brew cleanup nghttp2`...
# Removing: /usr/local/Cellar/nghttp2/1.46.0... (17 files, 2.2MB)
# ==> Upgrading cryptominisat
#   5.8.0_1 -> 5.8.0_2
#
# ==> Installing dependencies for cryptominisat: boost
# ==> Installing cryptominisat dependency: boost
# ==> Pouring boost--1.78.0_1.big_sur.bottle.tar.gz

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.0'

# %%
import tensorflow_datasets as tfds 
import matplotlib.pyplot as plt

# %%
# Import helper functions file
# !wget https://raw.githubusercontent.com/Yuuuugo/Food101/main/helper_functions.py
# Out:
# zsh:1: command not found: wget

# %%
from helper_functions import *

# %%
(train_data, test_data ),info = tfds.load(name ="food101",
                                              split = ["train","validation"],
                                              shuffle_files = True,
                                              as_supervised = True,
                                              with_info = True)
# Out:
# Downloading and preparing dataset food101/2.0.0 (download: 4.65 GiB, generated: Unknown size, total: 4.65 GiB) to /root/tensorflow_datasets/food101/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/food101/2.0.0.incompleteGXJT4P/food101-train.tfrecord
#   0%|          | 0/75750 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/food101/2.0.0.incompleteGXJT4P/food101-validation.tfrecord
#   0%|          | 0/25250 [00:00<?, ? examples/s]
# Dataset food101 downloaded and prepared to /root/tensorflow_datasets/food101/2.0.0. Subsequent calls will reuse this data.

# %%
class_names = info.features["label"].names
class_names[:10]
# Out:
# ['apple_pie',
#  'baby_back_ribs',
#  'baklava',
#  'beef_carpaccio',
#  'beef_tartare',
#  'beet_salad',
#  'beignets',
#  'bibimbap',
#  'bread_pudding',
#  'breakfast_burrito']

# %%
#Explore the Data 
sample = train_data.take(1)
sample
# Out:
# <TakeDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>

# %%
for image, label in sample :
  print(f"""
        Image shape : {image.shape}
        Image datatype : {image.dtype}
        Class format : {label}
        """)
# Out:
#         Image shape : (512, 382, 3)
#         Image datatype : <dtype: 'uint8'>
#         Class format : 73

# %%
#Visualize an image
plt.imshow(image)
plt.title(f"""Class name : { class_names[label.numpy()]}""")
plt.axis(False)

#Try to do it for several images and not only one
# Out:
# (-0.5, 381.5, 511.5, -0.5)

# %%
# Preprocessing the data
def preprocessing_image(image, label, img_shape = 224):
  """
  Change the image type form uint8 to float32, reshape them to (224,224,3) and scale them between 0 and 1 if necessary
  """
  #image = tf.resize(image, (img_shape, img_shape,3)) # for tf > 2.8
  image = tf.image.resize(image, [img_shape, img_shape]) # for tf = 2.4
  image = tf.cast(image, tf.float32)
  # image = image/255 # Not required if using EfficientNetBX models 
  return image,label

# We have to keep the label in the function even if we don't do modify it since we will use this in the map function that take both image and label as 
# an input

# %%
# Batch and prepare the datasets
train_data = train_data.map(map_func = preprocessing_image,
                            num_parallel_calls = tf.data.AUTOTUNE)
train_data = train_data.shuffle(buffer_size = 1000).batch(batch_size = 32).prefetch(buffer_size = tf.data.AUTOTUNE)

test_data = test_data.map(map_func = preprocessing_image,num_parallel_calls = tf.data.AUTOTUNE).batch(batch_size = 32).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
#Set the CALLBACKS to use 

CHECKPOINT_PATH = "model_checkpoint/cp.cpkt"

model_checkpoint = [
      tf.keras.callbacks.ModelCheckpoint(filepath = CHECKPOINT_PATH,
                                         monitor = "vall_acc",
                                         save_best_only = True,
                                         save_weights_only = True
                                         )
]

# %%
# Set up MixedPrecision Training
from tensorflow.keras import mixed_precision # with tf 2.8

mixed_precision.set_global_policy("mixed_float16")
mixed_precision.global_policy()
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: Tesla T4, compute capability 7.5
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: Tesla T4, compute capability 7.5
# <Policy "mixed_float16">

# %%
# Build the feature extractor model

from tensorflow.keras import layers 
from tensorflow.keras.layers.experimental import preprocessing

input_shape = (224,224,3)
base_model = tf.keras.applications.EfficientNetB0(include_top = False)
base_model.trainable = False

inputs = layers.Input(shape = input_shape, name = "input_layers")
#x = preprocessing.Rescaling(1/255.)(inputs) # Not Necessary with EfficientNetBX
x = base_model(inputs, training = False) # Don't want to retrain the EfficientNet for now 
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(101)(x)
outputs = layers.Activation("softmax", dtype = tf.float32, name = "output_layer")(x)

model = tf.keras.Model(inputs = inputs, outputs = outputs)

# %%
# Compile the model
model.compile(
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"],
    optimizer = tf.keras.optimizers.Adam()
)

# %%
# Check if the model is using mix policies layers per layers
for layer in model.layers:
  print(layer.name, layer.trainable, layer.dtype, layer.dtype_policy)
# Out:
# input_layers True float32 <Policy "float32">
# efficientnetb0 False float32 <Policy "mixed_float16">
# global_average_pooling2d True float32 <Policy "mixed_float16">
# dense True float32 <Policy "mixed_float16">
# output_layer True float32 <Policy "float32">

# %%
# Train the model 
history_feature_extract_model = model.fit(
    train_data,
    epochs = 3,
    steps_per_epoch = len(train_data),
    callbacks = [create_tensorboard_callback(dir_name = "training_logs",experiment_name ="efficientnetB0_logs"), model_checkpoint],
    validation_data = test_data,
    validation_steps = int(0.15*len(test_data))
)
# Out:
# Saving TensorBoard log files to: training_logs/efficientnetB0_logs/20220420-205004
# Epoch 1/3
# 2368/2368 [==============================] - 184s 71ms/step - loss: 2.3241 - accuracy: 0.4647 - val_loss: 1.2328 - val_accuracy: 0.6803
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# Epoch 2/3
# 2368/2368 [==============================] - 170s 71ms/step - loss: 1.3110 - accuracy: 0.6622 - val_loss: 1.1198 - val_accuracy: 0.6973
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# Epoch 3/3
# 2368/2368 [==============================] - 171s 71ms/step - loss: 1.1447 - accuracy: 0.7025 - val_loss: 1.0971 - val_accuracy: 0.7044
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.

# %%
model.save("Efficient_Net0-acc70.h5")

# %%
# Build the feature extractor model



input_shape = (224,224,3)
base_model = tf.keras.applications.EfficientNetB0(include_top = False)
base_model.trainable = False

inputs = layers.Input(shape = input_shape, name = "input_layers")
#x = preprocessing.Rescaling(1/255.)(inputs) # Not Necessary with EfficientNetBX
x = base_model(inputs, training = False) # Don't want to retrain the EfficientNet for now 
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(101)(x)
outputs = layers.Activation("softmax", dtype = tf.float32, name = "output_layer")(x)

model = tf.keras.Model(inputs = inputs, outputs = outputs)

# %%
n = len(model.layers[1].layers)
for i in range(1,10):
  model.layers[1].layers[n-i].trainable = True

# %%
# Compile the model
model.compile(
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"],
    optimizer = tf.keras.optimizers.Adam()
)

# %%
# Train the model 
history_feature_extract_model = model.fit(
    train_data,
    epochs = 3,
    steps_per_epoch = len(train_data),
    callbacks = [create_tensorboard_callback(dir_name = "training_logs",experiment_name ="efficientnetB0_logs"), model_checkpoint],
    validation_data = test_data,
    validation_steps = int(0.15*len(test_data))
)
# Out:
# Saving TensorBoard log files to: training_logs/efficientnetB0_logs/20220420-212712
# Epoch 1/3
# 2368/2368 [==============================] - 187s 74ms/step - loss: 2.3275 - accuracy: 0.4643 - val_loss: 1.2262 - val_accuracy: 0.6819
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# Epoch 2/3
# 2368/2368 [==============================] - 172s 72ms/step - loss: 1.3090 - accuracy: 0.6639 - val_loss: 1.1213 - val_accuracy: 0.7039
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# Epoch 3/3
# 2368/2368 [==============================] - 169s 71ms/step - loss: 1.1500 - accuracy: 0.7028 - val_loss: 1.0980 - val_accuracy: 0.7013
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
# WARNING:tensorflow:Can save best model only with vall_acc available, skipping.
